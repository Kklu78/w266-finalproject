# %%
from pymed import PubMed
import pandas as pd
pubmed = PubMed(tool="PubMedSearcher", email="myemail@ccc.com")

## PUT YOUR SEARCH TERM HERE ##
search_term = "nutrition"
results = pubmed.query(search_term, max_results=500)
articleList = []
articleInfo = []

for article in results:
# Print the type of object we've found (can be either PubMedBookArticle or PubMedArticle).
# We need to convert it to dictionary with available function
    articleDict = article.toDict()
    articleList.append(articleDict)

# Generate list of dict records which will hold all article details that could be fetch from PUBMED API
for article in articleList:
#Sometimes article['pubmed_id'] contains list separated with comma - take first pubmedId in that list - thats article pubmedId
    pubmedId = article['pubmed_id'].partition('\n')[0]
    # Append article info to dictionary 
    articleInfo.append({u'pubmed_id':pubmedId,
                       u'title':article['title'] if 'title' in article else 'None',
                       u'keywords':article['keywords'] if 'keywords' in article else 'None',
                       u'journal':article['journal'] if 'journal' in article else 'None',
                       u'abstract':article['abstract'] if 'abstract' in article else 'None',
                       u'conclusions':article['conclusions'] if 'conclusions' in article else 'None',
                       u'methods':article['methods'] if 'methods' in article else 'None',
                       u'results': article['results'] if 'results' in article else 'None',
                       u'copyrights':article['copyrights'] if 'copyrights' in article else 'None',
                       u'doi':article['doi'] if 'doi' in article else 'None',
                       u'publication_date':article['publication_date'] if 'publication_date' in article else 'None', 
                       u'authors':article['authors'] if 'authors' in article else 'None'})

# %%
# Generate Pandas DataFrame from list of dictionaries
articlesPD = pd.DataFrame.from_dict(articleInfo)
export_csv = articlesPD.to_csv (r'C:\Users\YourUsernam\Desktop\export_dataframe.csv', index = None, header=True) 

#Print first 10 rows of dataframe
articlesPD
# Out:
#     pubmed_id                                              title  \
# 0    34563076  Association between Change in Regional Phase A...
# 1    34563047  Screening for Copy Number Variations of the 15...
# 2    34563016  Gel-Based Materials for Ophthalmic Drug Delivery.
# 3    34562991  Reasons for and against Nutritional Interventi...
# 4    34562968  A Population Based Study of Liver Function amo...
# ..        ...                                                ...
# 495  34547034  Intestinal schistosomiasis among schoolchildre...
# 496  34547017  Biomarkers of dairy fat intake, incident cardi...
# 497  34547006  Efficacy of black rice extract on obesity in o...
# 498  34547005  Hand grip strength and health-related quality ...
# 499  34547002                             Letters to the Editor.
#
#                                               keywords  \
# 0    [BIA, bioelectrical impedance analysis, body c...
# 1    [DNA copy number variation, biomarkers, cholin...
# ...

# %%
articlesPD.shape
# Out:
# (500, 12)

# %%
articlesPD.isna().sum()
# Out:
# pubmed_id             0
# title                 0
# keywords              0
# journal               0
# abstract             39
# conclusions         431
# methods             495
# results             337
# copyrights          145
# doi                   7
# publication_date      0
# authors               0
# dtype: int64
